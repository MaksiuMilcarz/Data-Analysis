# %% [markdown]
# (group #: 35)
#
# (Bruna Cavalcanti Lauro, Igor Świerlikowski, Maksymilian Milcarz)
#
# (i6344286 ,i6360724 ,i6360886)
#
# **Use of genAI tools (e.g. chatGPT), websites (e.g. stackoverflow)**: *list websites where you found code (or other info) as well as include information on how you used genAI tools*

# %% [markdown]
# # Data Analysis
#
# # Clinic 2: I heard you are 👀 for a 🏠 in Utrecht
#
# By completing and delivering the clinic tasks you will know how to:
#
# - Work with real-world, messy datasets that require cleaning and preprocessing
# - Perform exploratory data analysis (EDA) to guide modeling decisions
# - Engineer new features, including spatial and polynomial features
# - Build reusable data processing pipelines in pandas
# - Train and evaluate linear and regularized models using scikit-learn
# - Use cross-validation to select model hyperparameters
# - Interpret models using feature importance techniques
# - Assess fairness by analyzing prediction errors across groups and locations
# - Communicate technical results clearly to both technical and non-technical audiences

# %% [markdown]
# **Important Dates.**
#
# - Clinic 2 release: Fri 06 Feb 2026
# - Clinic 2 due: Mon 23 Feb 2026 late night, wildcards available
#
# **Instructions for the deliverable: notebook and video**
#
# 1. Executed Notebook (.ipynb) (80 points)
#
# Your notebook should include the parts as here. All cells must be executed and outputs visible. Include answers to all questions and also explain your reasoning and describe any insights.
#
# ---
# 2. Short Video Presentation (up to 3 minutes) (20 points)
#
# Create a short video aimed at a **general (non-technical) audience** in which you explain:
#
# - What problem you were trying to solve
# - How you built your model (high level)
# - What features mattered most
# - Whether the model was fair across neighborhoods
# - One key insight or takeaway
#
# You do **not** need to include code in the video but you **should** include figures and plots. Focus on clarity, intuition and real-world implications.
#
# ---
# 🎯 Video Guidelines
#
# - Maximum length: **3 minutes**
# - Target audience: non-technical (e.g., city officials, homeowners, journalists)
# - You may use slides, screen recording or simple visuals
# - Avoid technical jargon as much as possible
# - Do **not** use AI-generated voices or AI video generators.
# - The presentation must use **your own voice**.
#
# ---
# ⚖️ Grading Considerations for the Video
#
# The video will be evaluated on:
#
# - Clarity of explanation
# - Correctness of interpretation
# - Engagement with fairness issues
# - Ability to communicate technical results simply
#
# ---
#
# 📅 Submission Format
#
# - Upload the executed notebook as `.ipynb`
# - Upload or link to your video (e.g., unlisted YouTube link, link to some storage space (e.g. google folder), other...)
#
# - **Honor code** applies to these tasks.
#   If you are not certain about an action, consult with Jerry.

# %% [markdown]
# **A philosophical note from Jerry on using Language Models (LMs)**
#
# You might have thought about it. Are LLMs going to replace data scientists?
#
# *Short answer*: No-one knows for sure. But, I have some hope.
#
#
# Here are my thoughts, for this clinic but in general as well. In many of our data analysis tasks we have 3 steps.
#
# + Step 1: Gather context and ask insightful questions. LLMs cannot deeply understand the nuanced desires, abilities, and personalities of complex organizations. At least for now 🙂
#
# + Step 2: Plan analyses that address your question(s). LLMs can provide advice as you weigh options. But, the choice of "best" analysis is often subjective. Experience matters. That's what people will pay you for in the future, not your ability to run Python.
#
# + Step 3: Run the analysis. With proper context and instructions, LLMs can help a lot here! But, you must be able to verify outputs. Don't do analysis by "vibes".

# %% [markdown]
# # 0. Introduction
#
# In this clinic, we will go through the iterative process of specifying, fitting, and refining a linear regression model using real-world housing data from Utrecht. Dataset is inspired from this [paper](https://ictinstitute.nl/utrecht-housing-dataset-2025/), which you are welcome to read!
#
# In the first part of the assignment, we will guide you through exploratory data analysis (EDA), laying out the thought process that leads to key data cleaning, transformation, and modeling decisions. We will then specify and fit increasingly refined linear models, providing examples of the type of code and workflow expected in the open-response section.
#
# The second part of the assignment is purposefully left open-ended. You will be allowed to build a linear model of your choice (e.g., linear regression, Ridge, Lasso) to better predict housing values.
#
# After completing this clinic, you should feel comfortable with:
#
# 1. Working with a real-world dataset that requires cleaning and preprocessing
#
# 1. Performing exploratory data analysis to inform modeling decisions
#
# 1. Building linear and regularized models using `sklearn`
#
# 1. Creating feature engineering pipelines with `pandas`
#
# 1. Using cross-validation for model selection and evaluation
#
# 1. Interpreting residuals and error metrics
#
# 1. Reflecting on fairness implications in predictive models
#
# ## Score breakdown
#
# Question | Points
# --- | ---
# [Question 1](#q1) | 5
# [Question 2a](#q2a) | 2
# [Question 2b](#q2b) | 2
# [Question 3](#q3) | 2
# [Question 4](#q4) | 8
# [Question 5](#q5) | 35
# [Question 6](#q6) | 15
# [Question 7](#q7) | 15
# Total | 80
#
# This score will be added to the video score (20), scaled down to 1 and that will be your final clinic score.

# %%
#necessary imports (edit as you see fit)
import numpy as np

import pandas as pd
from pandas.api.types import CategoricalDtype

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model as lm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# Plot settings
plt.rcParams['figure.figsize'] = (12, 9)
plt.rcParams['font.size'] = 12

#to show big values in numbers and not in scientific format
import matplotlib.ticker as mtick
pd.options.display.float_format = '{:,.2f}'.format
plt.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['axes.formatter.use_locale'] = False

# %% [markdown]
# ## 0.1 The Data
#
# The dataset consists of several hundred residential properties in Utrecht and includes structural, spatial, and energy-related features.
#
# Some of the key variables include, for more details refer to the `codebook.txt`:
#
# ```
# retailvalue – estimated market value of the property (our main prediction target)
#
# taxvalue – assessed value used for taxation purposes
#
# house-area, lot-area, garden-size – size-related features
#
# bathrooms, buildyear – structural characteristics
#
# energy-eff – energy efficiency indicator
#
# monument – whether the property is a protected historical building
#
# zipcode, x-coor, y-coor – location information
# ```
#
# Together, these variables describe both the physical properties of homes and aspects related to sustainability and urban geography.
#
# Dataset is not split to training/test but we will use one common seed (to rule all splits).
#
# ### 0.1.1 Housing Valuation and Fairness
#
# 🌍 In many countries, including the Netherlands, property values are used to determine: property taxes, mortgage conditions, insurance costs.
#
# 💰 These values are often estimated using statistical or machine learning models that take into account characteristics such as size, location, and building quality.
#
# 🎯 While predictive accuracy is important, valuation models can also have distributional consequences. Systematic overvaluation or undervaluation of homes in certain areas or categories (e.g., energy-efficient homes, historic buildings, or specific neighborhoods) can lead to: higher tax burdens for some residents, unfair advantages for others.
#
# 🧪 In this clinic, we will not only aim to build accurate predictive models, but also examine who benefits and who may be harmed by modeling errors.
#
# 🏠📊 By analyzing residuals and group-wise error patterns (e.g., by zipcode, energy efficiency or monument status), we will reflect on how fairness can be understood in the context of housing valuation. That will also serve as a good basis for the guest lecture we are going to have on March 9th.

# %% [markdown]
# ### 📥 Load the dataset

# %%
data = pd.read_csv("utrechthousing.csv")
print(data.shape)
data
# Out:
# (1895, 16)
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 0     100426     3528    11.10       5.00     55.50      112.50        10.50
# 1     100871     3528    13.60       5.00     68.00      112.50         8.00
# 2     100936     3800    16.60       6.70    111.20      150.75        44.20
# 3     100970     3800    18.60       6.00    111.60      108.00        39.60
# 4     101191     3800    19.60       6.00    117.60      108.00        45.60
# ...      ...      ...      ...        ...       ...         ...          ...
# 1890  951085     3528    14.00       7.00     98.00       94.50        14.00
# 1891  951376     3800    18.70      10.50    196.40      189.00        70.40
# 1892  951890     3528    14.50       9.20    133.40      207.00        50.60
# 1893  951932     3800    16.60      10.60    176.00      190.80        48.80
# 1894  952005     3525    10.10      10.20    103.00      137.70        10.20
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# 0           2    2112    5113       1932          1    494000       670000
# 1           0    2355    5218       1945          1    504000       675000
# 2           2    2656    5200       1946          1    692000       869000
# 3           2    2856    5201       1946          1    521000       628000
# 4           1    2962    5266       1950          1    526000       610000
# ...       ...     ...     ...        ...        ...       ...          ...
# 1890        1    2403    5260       1948          1    456000       628000
# 1891        2    2866    5317       1956          2    913000      1087000
# 1892        1    2451    5450       1967          1    935000      1176000
# 1893        2    2660    5466       1969          2    904000      1109000
# 1894        1    2009    5519       1967          1    633000       797000
#
#       energy-eff  monument
# 0              0         1
# 1              0         1
# 2              0         1
# 3              0         1
# 4              0         1
# ...          ...       ...
# 1890           0         1
# 1891           1         1
# 1892           0         1
# 1893           1         1
# 1894           0         0
#
# [1895 rows x 16 columns]

# %% [markdown]
# ### ✂️ Create train/test split
#
# Since the dataset is not pre-divided into training and test sets, we create our own split. The training set will be used to fit and tune our models, while the test set will be held out to evaluate performance on unseen data. To ensure reproducibility across different runs of the notebook, we fix the random seed before splitting.

# %%
# For reproducibility (so everyone gets the same split) ###DO NOT CHANGE
np.random.seed(1983)

# Split: 80% train, 20% test
training_data, testing_data = train_test_split(
    data, 
    test_size=0.2, 
    random_state=1983
)

# %% [markdown]
# As a good sanity check, we should at least verify that the data shape matches the description.

# %%
# Check sizes
#1516,16
print("Train shape:", training_data.shape)
#379,16
print("Test shape:", testing_data.shape)

# They should sum to full dataset
assert training_data.shape[0] + testing_data.shape[0] == data.shape[0]

# Same columns in both
assert set(training_data.columns) == set(testing_data.columns)
# Out:
# Train shape: (1516, 16)
# Test shape: (379, 16)

# %% [markdown]
# The next order of business is getting a feel for the variables in our data.  The Ames data set contains information that typical homebuyers would want to know.  A more detailed description of each variable is included in `codebook.txt`.  **You should take some time to familiarize yourself with the codebook before moving forward.** If you find any issues or inconsistencies in the codebook, please report them to us!

# %%
training_data.columns.values
# Out:
# array(['id', 'zipcode', 'lot-len', 'lot-width', 'lot-area', 'house-area',
#        'garden-size', 'balcony', 'x-coor', 'y-coor', 'buildyear',
#        'bathrooms', 'taxvalue', 'retailvalue', 'energy-eff', 'monument'],
#       dtype=object)

# %% [markdown]
# # 1. Guided Modeling
#
# In the first part of the assignment, we will take you step-by-step through one cycle of the modeling process.  Along the way, we will provide commentary to give you a sense of the thought process that goes into building a model. We give examples on most of the common cases we have explored (EDA, missing values, feature engineering etc.), but feel free to extend this analyses for your final model.
#
# ## 1.1 EDA
# Naturally, the first thing we want to do is get a feel for our data.  In this section, we will make a series of exploratory visualizations.  The plots we ask you to reproduce here are far from exhaustive. **When you build your own model in the second part of this assignment, you will want to delve deeper into the data.**
#
# Note that we will perform EDA on the **training data** so that information from the test data does not influence our modeling decisions.
#
# ### 1.1.1 Retail-value
# We begin by examining a [raincloud plot](https://www.kaggle.com/code/carlmcbrideellis/box-strip-violin-raincloud-plot) (yet another name for a combination of a KDE, a boxplot, and a boxplot all-in-one) of our target variable `SalePrice`.  At the same time, we also take a look at some descriptive statistics of this variable.

# %%
fig, axs = plt.subplots(nrows=2)

sns.histplot(
    training_data["retailvalue"],
    kde=True,
    ax=axs[0]
)

sns.stripplot(
    training_data["retailvalue"],
    orient="h",
    jitter=0.4,
    size=3,
    ax=axs[1],
    alpha=0.3
)

sns.boxplot(
    training_data["retailvalue"],
    orient="h",
    width=0.4,
    ax=axs[1],
    showfliers=False,
)

# Align axes
spacer = np.max(training_data["retailvalue"]) * 0.05
xmin = np.min(training_data["retailvalue"]) - spacer
xmax = np.max(training_data["retailvalue"]) + spacer
axs[0].set_xlim((xmin, xmax))
axs[1].set_xlim((xmin, xmax))

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_visible(False)
axs[1].yaxis.set_visible(False)

plt.subplots_adjust(hspace=0)
axs[1].set_facecolor("white")
#remove scientific format
axs[1].xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# %%
#Summary statistics for price
training_data["retailvalue"].describe()
# Out:
# count       1,516.00
# mean      791,773.75
# std       211,424.32
# min       419,000.00
# 25%       632,750.00
# 50%       768,000.00
# 75%       911,500.00
# max     1,428,000.00
# Name: retailvalue, dtype: float64

# %% [markdown]
# To check your understanding of the graph and summary statistics above, answer the following `True` or `False` questions:
#
# 1. The distribution of `retailvalue` in the training set is left-skew.
# 1. The mean of `retailvalue` in the training set is greater than the median.
# 1. 75% of the houses in the training set sold for less than 911,250.00. euro
#
# If you have trouble answering the questions above, discuss them in class with each other and confirm with a TA

# %%
# Answers:

# 1. False, its skewed to the right
# 2. True, thats what right skewed means
# 3. True, mostly, its estimated retail value not its sold value...

# %% [markdown]
# ### 1.1.2 Retail Value vs House Area
#
# Next, we examine `retailvalue` vs `house-area` (living area in m²).

# %%
g= sns.jointplot(
    x="house-area",
    y="retailvalue",
    data=training_data,
    kind="reg",
    ratio=4,
    space=0,
    scatter_kws={"s": 12, "alpha": 0.25},
    line_kws={"color": "black"}
)

g.ax_joint.xaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))
g.ax_joint.yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

# %% [markdown]
# We often expect a roughly linear relationship between size and value, but we should also look for unusual points (potential outliers). In this dataset, a small number of houses have house-area above 300 m². Let’s inspect them.

# %%
# q2house1 and q2house2 should be integers
q2house1 = training_data.loc[training_data["house-area"] > 300, "id"].iloc[0].item()
q2house2 = training_data.loc[training_data["house-area"] > 300, "id"].iloc[1].item()

q2house1, q2house2
# Out:
# (631929, 642836)

# %% [markdown]
# Below we write a function `remove_outliers` that removes outliers from a data set based off a threshold value of a variable. For example, `remove_outliers(training_data, 'house-area', upper=300)` should return a data frame with only observations that satisfy `house-area` less than or equal to 300.

# %%
def remove_outliers(data, variable, lower=-np.inf, upper=np.inf):
    """
    Input:
      data (data frame): the table to be filtered
      variable (string): the column with numerical outliers
      lower (numeric): observations with values lower than this will be removed
      upper (numeric): observations with values higher than this will be removed
    
    Output:
      a winsorized data frame with outliers removed
    """
    return data.loc[(data[variable] > lower) & (data[variable] < upper)]


training_data = remove_outliers(training_data, "house-area", upper=300)

# %%
#making sure the two observations were removed
assert training_data.shape[0] == 1514

# %% [markdown]
# ### 1.1.3 Zipcode vs Retail Value
#
# Next we explore this relationship. We have a small set of 4-digit zipcodes. Location is often one of the strongest predictors of housing value, so let’s inspect how values differ across zipcodes.

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="zipcode",
    y="retailvalue",
    data=training_data.sort_values("zipcode"),
    ax=axs[0]
)

sns.countplot(
    x="zipcode",
    data=training_data.sort_values("zipcode"),
    ax=axs[1]
)

axs[0].axhline(
    y=training_data["retailvalue"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)

# %% [markdown]
# What do you think? Are there differences or maybe outliers?
#
# While the dataset includes a zipcode variable, these administrative boundaries are relatively coarse and may not fully capture finer-grained spatial patterns in housing prices. Homes that are geographically close to each other can belong to different zipcodes, while homes far apart may share the same zipcode. As a result, relying solely on zipcode may obscure important local effects related to accessibility, amenities, and neighborhood characteristics.
#
# To better represent spatial structure in the data, we will create a new variable that groups houses into data-driven neighborhoods based directly on their geographic coordinates (`x-coor` and `y-coor`). Using a simple clustering technique, we partition the city into contiguous spatial regions that reflect natural groupings of properties. These spatial neighborhoods provide a more flexible and fine-grained representation of location than zipcode alone.
#
# After constructing these spatial neighborhoods, we will identify the most expensive ones (based on median housing value) and create a binary indicator variable, `in_rich_neighborhood`, which marks whether a house lies in one of these high-value areas.
#
# This additional feature allows our models to incorporate local spatial effects more effectively and provides a useful lens for later fairness analysis, where we will examine whether prediction errors systematically differ across regions of the city.

# %%
from sklearn.cluster import KMeans

def add_spatial_neighborhoods(data, k=8, random_state=1983):
    data = data.copy()
    
    coords = data[["x-coor", "y-coor"]]
    
    kmeans = KMeans(n_clusters=k, random_state=random_state)
    data["spatial_neighborhood"] = kmeans.fit_predict(coords)
    
    return data

# %%
training_data = add_spatial_neighborhoods(training_data, k=8)
training_data["spatial_neighborhood"].value_counts()
# Out:
# spatial_neighborhood
# 0    210
# 3    202
# 6    192
# 5    192
# 7    192
# 1    184
# 2    178
# 4    164
# Name: count, dtype: int64

# %%
sns.scatterplot(
    x="x-coor",
    y="y-coor",
    hue="spatial_neighborhood",
    data=training_data,
    palette="tab10"
)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Data-driven Spatial Neighborhoods")
# Out:
# Text(0.5, 1.0, 'Data-driven Spatial Neighborhoods')

# %% [markdown]
# So now let's replot the previous figure but with this variable.

# %%
fig, axs = plt.subplots(nrows=2)

sns.boxplot(
    x="spatial_neighborhood",
    y="retailvalue",
    data=training_data.sort_values("spatial_neighborhood"),
    ax=axs[0]
)

sns.countplot(
    x="spatial_neighborhood",
    data=training_data.sort_values("spatial_neighborhood"),
    ax=axs[1]
)

axs[0].axhline(
    y=training_data["retailvalue"].median(),
    color="green",
    linestyle="dotted"
)

for patch in axs[1].patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    axs[1].annotate(f"{int(y)}", (x.mean(), y), ha="center", va="bottom")

axs[0].xaxis.set_visible(False)
axs[0].yaxis.set_major_formatter(mtick.StrMethodFormatter('{x:,.0f}'))

plt.subplots_adjust(hspace=0.01)

# %% [markdown]
# Okay, now we managed to have some more variation and seems that in some cases retail values differ by the location and the number of observations is not identical across zipcodes.
#
# Let's apply a simple binning trick and mark the top-3 locations by median retail value as “pricey neighborhoods”.

# %%
def find_pricey_neighborhoods(data, n=3, metric=np.median):
    """
    Returns a list of the top-n neighboorhoods by aggregated retailvalue (default: median).
    """
    tmp = data.groupby("spatial_neighborhood")["retailvalue"].agg(metric).sort_values(ascending=False)
    return tmp.head(n).index.tolist()

pricey_locs = find_pricey_neighborhoods(training_data, 3, np.median)
pricey_locs
# Out:
# /var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/1944340939.py:5: FutureWarning: The provided callable <function median at 0x10717cc20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   tmp = data.groupby("spatial_neighborhood")["retailvalue"].agg(metric).sort_values(ascending=False)
# [5, 7, 0]

# %% [markdown]
# And we can add such a categorization to the dataset

# %%
def add_in_pricey_neighborhood(data, locs):
    """
    Adds a binary column in_pricey_neighborhoods:
      1 if location is in the provided list, else 0
    """
    data = data.copy()
    data["in_pricey_neighborhoods"] = data["spatial_neighborhood"].isin(locs).astype(int)
    return data

training_data = add_in_pricey_neighborhood(training_data, pricey_locs)
assert training_data["in_pricey_neighborhoods"].isnull().sum() == 0

# %%
training_data.head()
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 818   473504     3500    15.10       8.50    128.40      191.25        26.40
# 423   292120     3800    16.10       8.60    138.50      116.10        35.30
# 296   233225     3525    11.20       6.50     72.80       87.75         7.80
# 1739  882688     3525    14.00      10.60    148.40      190.80        42.40
# 1126  603592     3500    19.70       6.60    130.00       89.10        50.80
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# 818         1    2509    5864       2003          1    868000       969000
# 423         2    2613    5511       1973          1    575000       721000
# 296         0    2119    5802       2001          1    409000       480000
# 1739        1    2400    5662       1982          2    882000      1068000
# 1126        1    2966    5856       2001          1    460000       479000
#
#       energy-eff  monument  spatial_neighborhood  in_pricey_neighborhoods
# 818            0         0                     6                        0
# 423            0         0                     5                        1
# 296            1         0                     2                        0
# 1739           1         1                     6                        0
# 1126           1         0                     0                        1

# %% [markdown]
# Bonus (curiosity): Which are these expensive neighboorhoods in Utrecht?
#
# Feel free to use (or adapt) this feature in your latter analysis.

# %%
# it seems like the center is more pricey, maybe a better aaproach would be spatial neighboorhoods as rings away from center?!

# ringed spatial neighborhood:
# ...

# %% [markdown]
# ## 1.2 Missing Data
#
# Let's see if our data set has any missing values.
#
# 👉 You should observe that there are no missing values in this dataset.

# %%
missing_counts = training_data.isnull().sum().sort_values(ascending=False)

assert isinstance(missing_counts, pd.Series)
assert missing_counts.size == training_data.shape[1]
assert set(missing_counts.index.values) == set(training_data.columns.values)

missing_counts
# Out:
# id                         0
# zipcode                    0
# spatial_neighborhood       0
# monument                   0
# energy-eff                 0
# retailvalue                0
# taxvalue                   0
# bathrooms                  0
# buildyear                  0
# y-coor                     0
# x-coor                     0
# balcony                    0
# garden-size                0
# house-area                 0
# lot-area                   0
# lot-width                  0
# lot-len                    0
# in_pricey_neighborhoods    0
# dtype: int64

# %% [markdown]
# ## 1.3 Feature Engineering
#
# In this section we will create a new feature out of existing ones through a simple data transformation.  When you move on to create your own model, you may want to try out more complex transformations.
#
# ### 1.3.1 House age
#
# We’ll create a variable `house_age` based on `buildyear`. Since the dataset does not include a valuation year column, we’ll define age relative to a fixed reference year (2025 is fine for this dataset).

# %%
def add_house_age(data, reference_year=2025):
    data = data.copy()
    data["house_age"] = reference_year - data["buildyear"]
    return data

training_data = add_house_age(training_data)

# %%
# Check that no missing values were created
assert ~training_data["house_age"].isnull().any()

# %%
training_data['house_age'].min()
# Out:
# np.int64(7)

# %% [markdown]
# ### 1.3.2 Total Outdoor Space
#
# Outdoor space can matter a lot for price. We create:
#
# ```total_outdoor = lot-area + garden-size```

# %%
def add_total_outdoor(data):
    data = data.copy()
    data["total_outdoor"] = data["lot-area"] + data["garden-size"]
    return data

# %%
# Simple check
training_data = add_total_outdoor(training_data)
assert ~training_data["total_outdoor"].isnull().any()
training_data
# Out:
#           id  zipcode  lot-len  lot-width  lot-area  house-area  garden-size  \
# 818   473504     3500    15.10       8.50    128.40      191.25        26.40
# 423   292120     3800    16.10       8.60    138.50      116.10        35.30
# 296   233225     3525    11.20       6.50     72.80       87.75         7.80
# 1739  882688     3525    14.00      10.60    148.40      190.80        42.40
# 1126  603592     3500    19.70       6.60    130.00       89.10        50.80
# ...      ...      ...      ...        ...       ...         ...          ...
# 312   240952     3800    17.60       7.00    123.20      126.00        46.20
# 1070  582898     3525    14.50       7.30    105.90      131.40        40.20
# 886   502518     3500    15.60       8.10    126.40      145.80        53.50
# 666   403969     3500    18.10       8.50    153.90      191.25        60.40
# 119   153787     3500    19.10       7.00    133.70       94.50        63.70
#
#       balcony  x-coor  y-coor  buildyear  bathrooms  taxvalue  retailvalue  \
# 818         1    2509    5864       2003          1    868000       969000
# 423         2    2613    5511       1973          1    575000       721000
# 296         0    2119    5802       2001          1    409000       480000
# 1739        1    2400    5662       1982          2    882000      1068000
# 1126        1    2966    5856       2001          1    460000       479000
# ...       ...     ...     ...        ...        ...       ...          ...
# 312         2    2759    5212       1946          2    603000       747000
# 1070        2    2454    5709       1992          2    610000       725000
# 886         2    2559    5614       1983          2    684000       826000
# 666         1    2805    5953       2017          2    888000       922000
# 119         1    2914    5907       2002          1    485000       503000
#
#       energy-eff  monument  spatial_neighborhood  in_pricey_neighborhoods  \
# 818            0         0                     6                        0
# 423            0         0                     5                        1
# 296            1         0                     2                        0
# 1739           1         1                     6                        0
# 1126           1         0                     0                        1
# ...          ...       ...                   ...                      ...
# 312            1         1                     3                        0
# 1070           1         0                     6                        0
# 886            1         0                     5                        1
# 666            1         0                     0                        1
# 119            0         0                     0                        1
#
#       house_age  total_outdoor
# 818          22         154.80
# 423          52         173.80
# 296          24          80.60
# 1739         43         190.80
# 1126         24         180.80
# ...         ...            ...
# 312          79         169.40
# 1070         33         146.10
# 886          42         179.90
# 666           8         214.30
# 119          23         197.40
#
# [1514 rows x 20 columns]

# %% [markdown]
# #### Question 1 <a id="q1"></a>
#
# Propose and justify at least two new features derived from existing variables.
# Explain why they might improve predictive performance and how they could affect fairness.
#
# (at this point we don't care if we are going to use them or not, we just make some hypothesis)

# %%
#code for feature 1

print(training_data['bathrooms'].min()) 

# house-area to bathrooms ratio - m2/bathroom
def add_log_area_bathroom_ratio(data):
    data = data.copy()
    ratio = data["house-area"] / data["bathrooms"].replace(0, np.nan)
    data["log_area_bathroom_ratio"] = np.log(ratio)
    return data

# large house with few bathrooms might be inconvinient and not luxurious enough, comined with log transform this detects those cases.
# Out:
# 1

# %% [markdown]
# justification for feature 1 (predictive+fairness)

# %%
#code for feature 2

# lot shape: perfect squares might be more valuable then some weird elongated lots: len/width ration (alwyas deviding bigger by smaller value)
def add_len_to_width_ratio(data):
    data = data.copy()
    data["len_width_ratio"] = (
        data[["lot-width", "lot-len"]].max(axis=1)
        / data[["lot-width", "lot-len"]].min(axis=1)
    )
    return data

# area alone can miss the value of square vs enlogated properties, old properties might also be more irregular

# %% [markdown]
# justification for feature 2 (predictive+fairness)
#
# predictive: large house with few bathrooms might be inconvinient and not luxurious enough, comined with log transform this detects those cases.
# fairness: Potential undervaluation for large families living in large houses with fewer bathrooms
#
#
# predictive: area alone can miss the value of square vs enlogated properties, old properties might also be more irregular
# fairness: might encode zoning into newer and older properties.

# %% [markdown]
# # 2. Modeling
#
# We’ve finally gotten to a point where we can specify a simple model. Since the Utrecht dataset is not pre-split into training and test files, we will create our own split. We will treat `utrechthousing.csv` as the complete dataset, use `train_test_split` to create `training_data` and `testing_data`, and then evaluate model performance on the test set.
#
# As before, we will keep our preprocessing in reusable functions so we can apply the exact same pipeline to both training and testing data.

# %%
# Load a fresh copy of the data
full_data = pd.read_csv("utrechthousing.csv")

# Reproducible split
training_data, testing_data = train_test_split(full_data, test_size=0.2, random_state=1983)

# Sanity checks
assert training_data.shape == (1516, 16) #note that we are re-loading the dataset here and we apply pre-processing again later
assert testing_data.shape == (379, 16)
assert set(training_data.columns) == set(testing_data.columns)

# %% [markdown]
# Below we copy the functions we used before (you can add yours of course or modify them). Actually, we expect that you adapt this part for the next part (Question 5) but feel free to already adapt it here aswell.

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns

def select_columns(data, *columns):
    return data.reindex(columns=columns)

def remove_outliers(data, variable, lower=-np.inf, upper=np.inf):
    return data.loc[(data[variable] > lower) & (data[variable] < upper)]

def add_house_age(data, reference_year=2025):
    data = data.copy()
    data["house_age"] = reference_year - data["buildyear"]
    return data

def add_total_outdoor(data):
    data = data.copy()
    data["total_outdoor"] = data["lot-area"] + data["garden-size"]
    return data

# added features
def add_len_to_width_ratio(data):
    data = data.copy()
    data["len_width_ratio"] = (
        data[["lot-width", "lot-len"]].max(axis=1)
        / data[["lot-width", "lot-len"]].min(axis=1)
    )
    return data

def add_log_area_bathroom_ratio(data):
    data = data.copy()
    ratio = data["house-area"] / data["bathrooms"].replace(0, np.nan)
    data["log_area_bathroom_ratio"] = np.log(ratio)
    return data



def fit_spatial_neighborhood_model(train_data, k=8, random_state=1337):
    coords = train_data[["x-coor", "y-coor"]]
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(coords)
    return kmeans

def add_spatial_neighborhood(data, kmeans):
    data = data.copy()
    data["spatial_neighborhood"] = kmeans.predict(data[["x-coor", "y-coor"]])
    return data

# select top 3 bottom 3
def fit_polar_clustering(train_data, k=20, random_state=42):
    # 1. Calculate center
    center_x = (train_data["x-coor"].max() + train_data["x-coor"].min())/2
    center_y = (train_data["y-coor"].max() + train_data["y-coor"].min())/2
    
    # 2. Polar transformation
    dx = train_data["x-coor"] - center_x
    dy = train_data["y-coor"] - center_y
    r = np.sqrt(dx**2 + dy**2)
    theta = np.arctan2(dy, dx)
    
    polar_df = pd.DataFrame({'r': r, 'theta': theta})
    
    # 3. Scale (Essential for Polar)
    scaler = StandardScaler()
    polar_scaled = scaler.fit_transform(polar_df)
    
    # 4. Fit
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(polar_scaled)
    
    return kmeans, scaler, (center_x, center_y)

def add_polar_clusters(data, kmeans, scaler, center):
    data = data.copy()
    center_x, center_y = center
    dx = data["x-coor"] - center_x
    dy = data["y-coor"] - center_y
    
    r = np.sqrt(dx**2 + dy**2)
    theta = np.arctan2(dy, dx)
    
    polar_df = pd.DataFrame({'r': r, 'theta': theta})
    polar_scaled = scaler.transform(polar_df)
    
    data["spatial_neighborhood_polar"] = kmeans.predict(polar_scaled)
    return data

# select top 1 as center
def fit_ring_clustering(train_data, k=4, random_state=42):
    center_x = (train_data["x-coor"].max() + train_data["x-coor"].min())/2
    center_y = (train_data["y-coor"].max() + train_data["y-coor"].min())/2
    
    dx = train_data["x-coor"] - center_x
    dy = train_data["y-coor"] - center_y
    dist_sq = (dx**2 + dy**2).values.reshape(-1, 1)
    
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(dist_sq)
    
    return kmeans, (center_x, center_y)

def add_ring_clusters(data, kmeans, center):
    data = data.copy()
    center_x, center_y = center
    dx = data["x-coor"] - center_x
    dy = data["y-coor"] - center_y
    dist_sq = (dx**2 + dy**2).values.reshape(-1, 1)
    
    data["spatial_neighborhood_ringKernel"] = kmeans.predict(dist_sq)
    return data



def find_rich_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood'):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby(column)["retailvalue"]
        .agg(metric)
        .sort_values(ascending=False)
    )
    return tmp.head(n).index.tolist()

def find_poor_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood'):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby(column)["retailvalue"]
        .agg(metric)
        .sort_values(ascending=True)
    )
    return tmp.head(n).index.tolist()

def add_in_rich_neighborhood(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_rich_neighborhood"] = data[column].isin(rich_clusters).astype(int)
    return data

def add_in_poor_neighborhood(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_poor_neighborhood"] = data[column].isin(rich_clusters).astype(int)
    return data

def add_in_city_center(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_city_center"] = data[column].isin(rich_clusters).astype(int)
    return data



def add_location_terms(data):
    """
    Adds simple nonlinear location terms to allow spatial curvature with linear models.
    """
    data = data.copy()
    data["x2"] = data["x-coor"] ** 2
    data["y2"] = data["y-coor"] ** 2
    data["xy"] = data["x-coor"] * data["y-coor"]
    return data

# %%
# --- 3. Visualization (FIXED) ---
def visualize_spatial_clusters(data, title_prefix="", column="spatial_neighborhood"):
    # Work on a copy to avoid SettingWithCopy warnings on the original df
    plot_data = data.copy()
    
    # *** FIX 1: Convert to String to ensure Dictionary Keys match Plot Categories ***
    plot_data[column] = plot_data[column].astype(str)
    
    # Get unique clusters and sort them numerically so the legend isn't random
    unique_clusters = sorted(plot_data[column].unique(), key=lambda x: int(x))
    n_clusters = len(unique_clusters)
    
    # Use a high-contrast palette (tab10 or Set1)
    palette_values = sns.color_palette("tab10", n_clusters)
    
    # Map Cluster String -> Color
    color_map = dict(zip(unique_clusters, palette_values))
    
    # Determine Order by Median Value (for Boxplot)
    order = (
        plot_data.groupby(column)["retailvalue"]
        .median()
        .sort_values()
        .index
        .tolist()
    )

    fig, axes = plt.subplots(1, 2, figsize=(18, 7))
    
    # --- Plot A: Boxplot ---
    # We map 'hue' to the same variable as 'x' to strictly enforce the palette
    sns.boxplot(
        data=plot_data, 
        x=column, 
        y="retailvalue", 
        order=order,
        hue=column, # Explicitly set hue to fix palette issue
        palette=color_map, 
        dodge=False, # Keeps boxes centered
        ax=axes[0]
    )
    axes[0].legend([],[], frameon=False) # Hide redundant legend in boxplot
    axes[0].set_title(f"{title_prefix}: Retail Value Distribution")
    axes[0].set_xlabel("Cluster ID")
    axes[0].set_ylabel("Retail Value")
    axes[0].grid(axis='y', linestyle='--', alpha=0.5)

    # --- Plot B: Scatter Plot ---
    sns.scatterplot(
        data=plot_data, 
        x="x-coor", 
        y="y-coor", 
        hue=column, 
        hue_order=unique_clusters, # Ensure legend order matches logic
        palette=color_map,         # FORCE SAME COLORS
        s=20, 
        edgecolor='k',             # Add edge for contrast
        linewidth=0.1,
        alpha=0.9,
        ax=axes[1]
    )
    
    # Mark the center
    center_x = plot_data["x-coor"].mean()
    center_y = plot_data["y-coor"].mean()
    axes[1].scatter(center_x, center_y, c='black', s=150, marker='X', label='Center')
    
    axes[1].set_title(f"{title_prefix}: Spatial Layout")
    axes[1].legend(bbox_to_anchor=(1.02, 1), loc='upper left', title="Cluster ID")
    axes[1].axis('equal')
    
    plt.tight_layout()
    plt.show()

# --- 4. Execution ---

# 1. Run Polar
print("Running Polar Clustering...")
polar_k, polar_scaler, polar_center = fit_polar_clustering(training_data, k=20)
print(f"Polar Clustering: Center at {polar_center}, K={polar_k.n_clusters}")
df_polar = add_polar_clusters(training_data, polar_k, polar_scaler, polar_center)
visualize_spatial_clusters(df_polar, "Polar (Direction & Distance)", 'spatial_neighborhood_polar')

# 2. Run Ring
print("Running Ring Clustering...")
ring_k, ring_center = fit_ring_clustering(training_data, k=4)
print(f"Ring Clustering: Center at {ring_center}, K={ring_k.n_clusters}")
df_ring = add_ring_clusters(training_data, ring_k, ring_center)
visualize_spatial_clusters(df_ring, "Ring (Distance Squared)", 'spatial_neighborhood_ringKernel')
# Out:
# Running Polar Clustering...
# Polar Clustering: Center at (np.float64(2484.5), np.float64(5484.5)), K=20
# Running Ring Clustering...
# Ring Clustering: Center at (np.float64(2484.5), np.float64(5484.5)), K=4

# %% [markdown]
# Better neighborhood selection:
#
# Yes code is AI generated, but the idea of using the x^2+y^2 kernel and polar coordinates is mine!
#
# Those are more detailed and present more realistic boundires for neighboorhood selection, under the centrality and city sprawling assumption

# %% [markdown]
# ## 2.1 Reusable Pipeline
#
# Throughout this assignment, you should notice that your data flows through a single processing pipeline several times.  From a software engineering perspective, this should be sufficient motivation to abstract parts of our code into reusable functions/methods.  We will now encapsulate our entire pipeline into a single function `process_data_gm`.  gm is shorthand for "guided model".

# %%
## 2.1 Reusable Pipeline

def select_columns(data, *columns):
    return data.reindex(columns=columns)

def process_data_gm1(data):
    # -------------------
    # Clean Data
    # -------------------
    data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)
    data = add_total_outdoor(data)
    # data = add_len_to_width_ratio(data)
    # data = add_log_area_bathroom_ratio(data)
    
    # Neighborhood clustering
    # polar_k, polar_scaler, polar_center = fit_polar_clustering(data, k=20)
    # data = add_polar_clusters(data, polar_k, polar_scaler, polar_center)
    # ring_k, ring_center = fit_ring_clustering(data, k=4)
    # data = add_ring_clusters(data, ring_k, ring_center)

    # rich_cluster_3 = find_rich_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar')
    # rich_cluster_1 = find_rich_spatial_neighborhoods(data, n=1, metric=np.median, column = 'spatial_neighborhood_ringKernel')
    # poor_cluster_3 = find_poor_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar')
    # data = add_in_rich_neighborhood(data, rich_cluster_3, column = 'spatial_neighborhood_polar')
    # data = add_in_poor_neighborhood(data, poor_cluster_3, column = 'spatial_neighborhood_polar')
    # data = add_in_city_center(data, rich_cluster_1, column = 'spatial_neighborhood_ringKernel')

    # -------------------
    # Select modeling columns
    # -------------------
    data = select_columns(
        data,
        "retailvalue",
        "house-area",
        "bathrooms",
        "total_outdoor",
        "house_age",
        "balcony",
        "energy-eff",
        "monument"#, 'log_area_bathroom_ratio' , 'len_width_ratio',
        
        # 'in_rich_neighborhood', 'in_poor_neighborhood', 'in_city_center'
    )

    # -------------------
    # Split predictors/target
    # -------------------
    X = data.drop(["retailvalue"], axis=1)
    y = data["retailvalue"]

    return X, y

# %% [markdown]
# An alternative way of writing the same code above explicitly allows us to think about our data flowing through a [pipeline](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pipe.html) where the output of one function is the input of the next.  Carefully thought out function names make the code self-documenting: you can just read off the intended high-level processing steps from top to bottom.
#
# You are not required to use this style of coding.  We just wanted to point out that it exists.

# %%
# def process_data_gm1(data):
#     data = (
#         data
#         # Clean Data
#         .pipe(remove_outliers, "house-area", upper=300)
#         # -------------------
#         # Transform Data
#         .pipe(add_house_age)
#         .pipe(add_total_outdoor)
#         # -------------------
#         # Select columns
#         .pipe(select_columns,
#               "retailvalue",
#               "house-area",
#               "bathrooms",
#               "total_outdoor",
#               "house_age",
#               "balcony",
#               "energy-eff",
#               "monument")
#     )
#     X = data.drop(["retailvalue"], axis=1)
#     y = data["retailvalue"]
#     return X, y

# %% [markdown]
# ## 2.2 Fitting our first model
#
# We are finally going to fit a model (yay!). This part is slightly unceremonious since we did much of the heavy lifting in the previous sections. The model we will fit can be written as follows:
#
# $$
# \begin{align}
# \text{retailvalue} =\;& \theta_0
# + \theta_1 \times \text{HouseArea}
# + \theta_2 \times \text{Bathrooms} \\
# &+ \theta_3 \times \text{TotalOutdoor}
# + \theta_4 \times \text{HouseAge} \\
# &+ \theta_5 \times \text{EnergyEfficiency}
# + \theta_6 \times \text{Monument}
# + \theta_7 \times \text{Balcony}
# \end{align}
# $$
#
# where:
#
# - `HouseArea` corresponds to `house-area`
# - `Bathrooms` corresponds to `bathrooms`
# - `TotalOutdoor = lot-area + garden-size`
# - `HouseAge = current year − buildyear`
# - `EnergyEfficiency` corresponds to `energy-eff`
# - `Monument` is an indicator for historic buildings
# - `Balcony` is an indicator for balcony presence
#
#
# #### Question 2a <a name="q1a"></a>
# Remove the commenting and fill in the ellipses `...` below with `X_train`, `y_train`, `X_test`, or `y_test`.

# %%
# Pre-process our training and test data in exactly the same way
# Our functions make this very easy!
X_train, y_train = process_data_gm1(training_data)
X_test, y_test = process_data_gm1(testing_data)
guidedmodel1 = lm.LinearRegression(fit_intercept=True)

# Fill in the ... below with X_train, y_train, X_train, or X_test.
# Remember to uncomment
guidedmodel1.fit(X_train, y_train)
y_fitted = guidedmodel1.predict(X_train)
y_predicted = guidedmodel1.predict(X_test)

# %%
#print the result

print(y_fitted.mean())
print(y_predicted.mean())
# Out:
# 791103.6988110965
# 785924.2617644886

# %%
#if you fail these, might still be okay (but good to check your model, split etc.)
assert 790000 <= y_fitted.mean() <= 8000000
assert 780000 <= y_predicted.mean() <= 790000

# %%
# Mean prediction should not be wildly off from mean actual target in training/test
assert abs(y_fitted.mean() - y_train.mean()) / y_train.mean() < 0.25
assert abs(y_predicted.mean() - y_test.mean()) / y_test.mean() < 0.25

# %% [markdown]
# In this assignment, we will use Root-Mean-Square Error (RMSE) to measure the quality of our models.  As a reminder, this quantity is defined as:
#
# $$RMSE = \sqrt{\dfrac{\sum_{\text{houses in test set}}(\text{actual price of house} - \text{predicted price of house})^2}{\text{# of houses in test set}}}$$
#
# #### Question 2b <a name="q1b"></a>
#
# Write a function `rmse` that calculates the RMSE of a model.  Again, make sure you are taking advantage of vectorized code.  This can be solved without any iteration.

# %%
def rmse(actual, predicted):
    """
    Calculates RMSE from actual and predicted values
    Input:
      actual (1D array-like): vector of actual values
      predicted (1D array-like): vector of predicted/fitted values
    Output:
      a float, the root-mean square error
    """
    #your code goes here 
    return np.sqrt(np.mean((actual - predicted) ** 2))

# %%
#print the error

rmse_value = rmse(y_test, y_predicted)
print(rmse_value)
print(y_test.std())
# Out:
# 36952.056820810416
# 204960.0020362511

# %%
# RMSE should be smaller than the spread (std) of the target, otherwise the model is doing very poorly
assert rmse_value < y_test.std()
assert 10_000 <= rmse(y_test, y_predicted) <= 37_000

# %% [markdown]
# ## 2.3 Checking our model: Residual Plots
#
# Recall from the lectures that one way of diagnosing a model is through a residual plot. Here we plot the actual housing values (`retailvalue`) against the residuals of the model. Ideally, we would see a horizontal line of points at 0 (perfect prediction!). The next best outcome would be a roughly homogeneous cloud of points centered around 0.
#
# However, since our first model is intentionally simple, we may observe systematic patterns in the residuals. In particular, it is common for linear models to underpredict very expensive homes and overpredict cheaper ones. Such patterns indicate that the model is underfitting and failing to capture more complex relationships in the data. You will likely want to address these issues when building your own final model in the open-response section.

# %%
gm1_residuals = y_test - y_predicted

ax = sns.regplot(x=y_test, y=gm1_residuals)
ax.set_xlabel("Retail Value (Test Data)")
ax.set_ylabel("Residuals (Actual Value - Predicted Value)")
# Out:
# Text(0, 0.5, 'Residuals (Actual Value - Predicted Value)')

# %% [markdown]
# ## 2.4 Regularizing our model
#
# Ok, so let's make our modeling a little more fancy by regularizing the coefficients. This second model will use the Lasso, but you are free to use Ridge or other regularized linear models in your own work.
#
# Before applying regularization, we need to standardize our predictor variables. This is necessary because regularization penalizes large coefficients, and variables measured on different scales would otherwise be treated unfairly. By standardizing each predictor to have mean 0 and standard deviation 1, we ensure that the penalty is applied consistently across features.
#
# #### Question 3 <a name="q3"></a>
#
# Write a function that standardizes the columns of a data frame containing only numeric columns.  Be sure to make use of vectorization.

# %%
def standardize_columns(data):
    '''
    Input:
      data (data frame): contains only numeric columns
    Output:
      data frame, the same data, except each column is standardized 
      to have 0-mean and unit variance
    '''
    #your code goes here [1 line should suffice, don't go nuclear]    
    return (data - data.mean()) / data.std()

# %%
# Simple test of the standardization function
test_standardize_df = standardize_columns(
   testing_data[["retailvalue", "house-area"]]
)

train_standardize_df = standardize_columns(
   training_data[["retailvalue", "house-area"]]
)

# Make sure the mean is approximately zero
assert -0.001 < test_standardize_df.mean().sum() < 0.001

# Make sure the standard deviation is approximately one
assert 1.9 < test_standardize_df.std().sum() < 2.1

# %% [markdown]
# We will now define a new processing pipeline for our regularized model. This pipeline is similar to the one used for the simple linear regression model, except that we standardize the predictor variables before fitting the model.

# %%
def process_data_gm2(data):
    # -------------------
    # Clean Data
    # -------------------
    data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)
    data = add_total_outdoor(data)
    # data = add_len_to_width_ratio(data)
    # data = add_log_area_bathroom_ratio(data)
    
    # Neighborhood clustering
    # polar_k, polar_scaler, polar_center = fit_polar_clustering(data, k=20)
    # data = add_polar_clusters(data, polar_k, polar_scaler, polar_center)
    # ring_k, ring_center = fit_ring_clustering(data, k=4)
    # data = add_ring_clusters(data, ring_k, ring_center)

    # rich_cluster_3 = find_rich_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar')
    # rich_cluster_1 = find_rich_spatial_neighborhoods(data, n=1, metric=np.median, column = 'spatial_neighborhood_ringKernel')
    # poor_cluster_3 = find_poor_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar')
    # data = add_in_rich_neighborhood(data, rich_cluster_3, column = 'spatial_neighborhood_polar')
    # data = add_in_poor_neighborhood(data, poor_cluster_3, column = 'spatial_neighborhood_polar')
    # data = add_in_city_center(data, rich_cluster_1, column = 'spatial_neighborhood_ringKernel')

    # -------------------
    # Select modeling columns
    # -------------------
    data = select_columns(
        data,
        "retailvalue",
        "house-area",
        "bathrooms",
        "total_outdoor",
        "house_age",
        "balcony",
        "energy-eff",
        "monument", 'x-coor', 'y-coor'   #, 'log_area_bathroom_ratio' , 'len_width_ratio',
        
        # 'in_rich_neighborhood', 'in_poor_neighborhood', 'in_city_center'
    )

    # -------------------
    # Split predictors/target
    # -------------------
    X = standardize_columns(data.drop(["retailvalue"], axis=1))
    y = data["retailvalue"]

    return X, y

# def process_data_gm2(data):

#     data = (
#         data
#         # -------------------
#         # Clean Data
#         # -------------------
#         .pipe(remove_outliers, "house-area", upper=300) 

#         # -------------------
#         # Feature engineering
#         # -------------------
#         .pipe(add_house_age)
#         .pipe(add_total_outdoor)
#         .pipe(add_len_to_width_ratio)
#         .pipe(add_log_area_bathroom_ratio)
        # 
    #     .pipe(add_polar_clusters, *fit_polar_clustering(data, k=20))
    #     .pipe(add_ring_clusters, *fit_ring_clustering(data, k=4))
        
    #     .pipe(add_in_rich_neighborhood, find_rich_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar'), column = 'spatial_neighborhood_polar')
    #     .pipe(add_in_poor_neighborhood, find_poor_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood_polar'), column = 'spatial_neighborhood_polar')
    #     .pipe(add_in_city_center, find_rich_spatial_neighborhoods(data, n=1, metric=np.median, column = 'spatial_neighborhood_ringKernel'), column = 'spatial_neighborhood_ringKernel')
    
    #     # -------------------
    #     # Select modeling columns
    #     # -------------------
    #     .pipe(select_columns,
    #           "retailvalue",
    #           "house-area",
    #           "bathrooms",
    #           "total_outdoor",
    #           "house_age",
    #           "balcony",
    #           "energy-eff",
    #           "monument",
    #           'log_area_bathroom_ratio' , 'len_width_ratio',
    #           'in_rich_neighborhood', 'in_poor_neighborhood', 'in_city_center'
    #           #, "x-coor","y-coor"
    #           )
    # )

    # # IMPORTANT: 
    # # Standardize predictors (but not the target)
    # # what will happen if we don't standardize?
    # X = standardize_columns(data.drop(["retailvalue"], axis=1))
    # y = data["retailvalue"]

    # return X, y

# %% [markdown]
# It may be instructive to see the cross-validation procedure explicitly once.  You should be able to understand what each part of the code is doing below, but we do not expect you to use this code for your own model (use [LassoCV](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html) instead).

# %%
# Process the data
X_train, y_train = process_data_gm2(training_data)
X_test, y_test = process_data_gm2(testing_data)

# Specify the model
guidedmodel2 = lm.Lasso(copy_X=True)

# Specify CV method and grid of regularization values
five_fold_cv = KFold(n_splits=5)
alphas = np.arange(0.001, 100, 0.5)

rmses = np.zeros(len(alphas))

# Grid search over alphas
for i, alpha in enumerate(alphas):
    guidedmodel2.set_params(alpha=alpha)
    model_rmse = 0

    for train_index, test_index in five_fold_cv.split(X_train):
        X_fold_train = X_train.iloc[train_index]
        y_fold_train = y_train.iloc[train_index]
        X_fold_test = X_train.iloc[test_index]
        y_fold_test = y_train.iloc[test_index]

        guidedmodel2.fit(X_fold_train, y_fold_train)
        y_fold_predicted = guidedmodel2.predict(X_fold_test)

        model_rmse += rmse(y_fold_test, y_fold_predicted)

    rmses[i] = model_rmse / 5

optimal_alpha = alphas[rmses == np.min(rmses)][0]

guidedmodel2.set_params(alpha=optimal_alpha)
guidedmodel2.fit(X_train, y_train)

y_predicted = guidedmodel2.predict(X_test)

print(f"The validation RMSE for this model with "
      f"alpha={optimal_alpha} is {rmse(y_test, y_predicted)}.")
# Out:
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.963e+10, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+10, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent(
# The validation RMSE for this model with alpha=25.001 is 25528.221013958595.

# %% [markdown]
# ### 2.4.1 Lasso Path
#
# Let’s examine how RMSE varies across different values of the regularization parameter ($\lambda$ in lecture, `alpha` in `sklearn`). This is known as the regularization path. The dashed red line marks the value of `alpha` that minimizes RMSE.

# %%
plt.plot(alphas, rmses)
plt.axvline(x=optimal_alpha, color="red", linestyle="dashed")

ax = plt.gca()
ax.set_title("Average LASSO RMSE Path")
ax.set_xlabel("Regularization Level (alpha)")
ax.set_ylabel("RMSE")
# Out:
# Text(0, 0.5, 'RMSE')

# %% [markdown]
# Alternative approach: You can also repeat the regularized regression using `LassoCV`, which automatically performs cross-validation over a grid of regularization values.

# %% [markdown]
# ### 2.4.2 Lasso Residual Plot
#
# Looking at the residual plot for our L1 regularized linear model, it's clear the regularization did not solve the problems we saw in the simple model.  It seems you have your work cut out for you!

# %%
gm2_residuals = y_test - y_predicted

ax = sns.regplot(x=y_test, y=gm2_residuals)
ax.set_xlabel("Retail Value (Test Data)")
ax.set_ylabel("Residuals (Actual Value - Predicted Value)")
# Out:
# Text(0, 0.5, 'Residuals (Actual Value - Predicted Value)')

# %% [markdown]
# #### Question 4
#
# The following questions are supposed to hep you understand the impact of regularization.
#
# 4a) Does adding location features change the chosen `alpha` compared to the non-location model?
#
# 4b) Does the test RMSE improve?
#
# 4c) How many coefficients become exactly zero? Which ones?
#
# 4d) Do you observe any signs of underfitting or overfitting in residual plots after adding location?
#
# Note: Regularization thrives in cases where the dataset is messy (or when there are correlations with the features so it's fine if you don't observe strong effects as we saw in class

# %%
# RMSE:
print(f"Test RMSE: {rmse(y_test, y_predicted)}")
print(f"Test R^2: {guidedmodel2.score(X_test, y_test)}")

print(f"Train RMSE: {rmse(y_train, guidedmodel2.predict(X_train))}")
# Out:
# Test RMSE: 25528.221013958595
# Test R^2: 0.9844457068774778
# Train RMSE: 25276.60133506801

# %%
# number of non-zero coefficients as percentage of total:
non_zero_coefs = np.sum(guidedmodel1.coef_ != 0)
total_coefs = len(guidedmodel1.coef_)
print(f"Model 1:   Non-zero coefficients: {non_zero_coefs} out of {total_coefs} ({non_zero_coefs/total_coefs:.1%})")


non_zero_coefs = np.sum(guidedmodel2.coef_ != 0)
total_coefs = len(guidedmodel2.coef_)
print(f"Model 2:   Non-zero coefficients: {non_zero_coefs} out of {total_coefs} ({non_zero_coefs/total_coefs:.1%})")
# which features are zero-coefficient:
zero_coef = X_train.columns[guidedmodel2.coef_ == 0]
print("Model 2:   Zero-coefficient features:", zero_coef.tolist())
# Out:
# Model 1:   Non-zero coefficients: 7 out of 7 (100.0%)
# Model 2:   Non-zero coefficients: 9 out of 9 (100.0%)
# Model 2:   Zero-coefficient features: []

# %%
# 4a: As expected adding exact coordinates does change the alpha parameter, 
# since adding the location allows the model to Heavily OVERFIT!!! the training data, 
# the optimal alpha is much higher than before, to compensate for this overfitting.

# 4b: The RMSE actually decreased considerably: 25528 vs. 36952, ~31% decrease, on the test set. 

# 4c: None, which is quite surprising, since we expected the model to rely heavily on the location features, 
# but it seems like it found some useful signal in the other features as well.
    
# 4d: Not much, Test RMSE ~ Train RMSE. If anything the residual plots look better!
# Note how the inital plot reveals a pattern about underprediction of cheap houses and overprediction of expensive houses, 
# While after adding location, the residuals are more randomly distributed and the residual regression is almost flat

# %% [markdown]
# # 3. Let's improve the model, bring out the big guns...
#
# In this part of the clinic, you are asked to go beyond the guided example and design your own predictive model.
#
# You may use any **linear model** discussed in class (perhaps with non-linear polynomial features). Your goal is to **improve prediction performance** on unseen data, measured using **Root Mean Squared Error (RMSE)**.
#
# ---
# ### 📋 What you should do
#
# 1. Construct new features based on existing variables:
#    - Spatial features (latitude, longitude, neighborhoods, clusters)
#    - Polynomial features (e.g., squared terms, interactions)
#    - Aggregated or transformed variables (e.g., total outdoor space, house age)
# 2. Select a set of predictors you believe will improve performance.
# 3. Build a reusable data processing pipeline (similar to the guided model).
# 4. Train a linear or regularized linear model using the training data.
# 5. Evaluate your model using RMSE on the test set.
#
# You are encouraged to experiment and justify your modeling choices.
#
# ---
#
# ### ⚠️ Overfitting Check
#
# - Models that perform extremely well on the training set but poorly on unseen data (we keep a set aside).
# - You should aim for a balance between accuracy and generalization.
#
# Using cross-validation and regularization is strongly recommended.

# %% [markdown]
# ### Grading Scheme
#
# Your model will be assessed based on:
#
# - Predictive performance (RMSE)
# - Soundness of your modeling pipeline
# - Feature engineering choices (including polynomial features where appropriate)
# - Evidence of avoiding overfitting
# - Clear explanation of your approach
#
# There is no single “correct” model — thoughtful experimentation is the goal.

# %% [markdown]
# #### Question 5 <a name="q3"></a>
#
# Just as in the guided model above, you should encapsulate as much of your workflow into functions as possible.  Define `process_data_fm` and `final model` in the cell below. In order to calculate your final model's RMSE, we will run the code in the cell after that.

# %%
# =========================
# Solution to Open-Response 
# =========================

import numpy as np
import pandas as pd

from sklearn import linear_model as lm
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import KFold, cross_val_predict
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error


# -------------------------
# Utility functions (e.g. rmse)
# -------------------------

def standardize_columns(data): 
    return (data - data.mean()) / data.std()

def rmse(actual, predicted):
    return np.sqrt(np.mean((actual - predicted) ** 2))


# -------------------------
# Feature engineering (everything you carry from parts 1 and 2)
# -------------------------

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import seaborn as sns

def select_columns(data, *columns):
    return data.reindex(columns=columns)

def remove_outliers(data, variable, lower=-np.inf, upper=np.inf):
    return data.loc[(data[variable] > lower) & (data[variable] < upper)]

def add_house_age(data, reference_year=2025):
    data = data.copy()
    data["house_age"] = reference_year - data["buildyear"]
    return data

def add_total_outdoor(data):
    data = data.copy()
    data["total_outdoor"] = data["lot-area"] + data["garden-size"]
    return data

# added features
def add_len_to_width_ratio(data):
    data = data.copy()
    data["len_width_ratio"] = (
        data[["lot-width", "lot-len"]].max(axis=1)
        / data[["lot-width", "lot-len"]].min(axis=1)
    )
    return data

def add_log_area_bathroom_ratio(data):
    data = data.copy()
    ratio = data["house-area"] / data["bathrooms"].replace(0, np.nan)
    data["log_area_bathroom_ratio"] = np.log(ratio)
    return data

# base neighborhoods
def fit_spatial_neighborhood_model(train_data, k=8, random_state=1337):
    coords = train_data[["x-coor", "y-coor"]]
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(coords)
    return kmeans

def add_spatial_neighborhood(data, kmeans):
    data = data.copy()
    data["spatial_neighborhood"] = kmeans.predict(data[["x-coor", "y-coor"]])
    return data

# select top 3 bottom 3
def fit_polar_clustering(train_data, k=20, random_state=42):
    # 1. Calculate center
    center_x = (train_data["x-coor"].max() + train_data["x-coor"].min())/2
    center_y = (train_data["y-coor"].max() + train_data["y-coor"].min())/2
    
    # 2. Polar transformation
    dx = train_data["x-coor"] - center_x
    dy = train_data["y-coor"] - center_y
    r = np.sqrt(dx**2 + dy**2)
    theta = np.arctan2(dy, dx)
    
    polar_df = pd.DataFrame({'r': r, 'theta': theta})
    
    # 3. Scale (Essential for Polar)
    scaler = StandardScaler()
    polar_scaled = scaler.fit_transform(polar_df)
    
    # 4. Fit
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(polar_scaled)
    
    return kmeans, scaler, (center_x, center_y)

def add_polar_clusters(data, kmeans, scaler, center):
    data = data.copy()
    center_x, center_y = center
    dx = data["x-coor"] - center_x
    dy = data["y-coor"] - center_y
    
    r = np.sqrt(dx**2 + dy**2)
    theta = np.arctan2(dy, dx)
    
    polar_df = pd.DataFrame({'r': r, 'theta': theta})
    polar_scaled = scaler.transform(polar_df)
    
    data["spatial_neighborhood_polar"] = kmeans.predict(polar_scaled)
    return data

# select top 1 as center
def fit_ring_clustering(train_data, k=4, random_state=42):
    center_x = (train_data["x-coor"].max() + train_data["x-coor"].min())/2
    center_y = (train_data["y-coor"].max() + train_data["y-coor"].min())/2
    
    dx = train_data["x-coor"] - center_x
    dy = train_data["y-coor"] - center_y
    dist_sq = (dx**2 + dy**2).values.reshape(-1, 1)
    
    kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
    kmeans.fit(dist_sq)
    
    return kmeans, (center_x, center_y)

def add_ring_clusters(data, kmeans, center):
    data = data.copy()
    center_x, center_y = center
    dx = data["x-coor"] - center_x
    dy = data["y-coor"] - center_y
    dist_sq = (dx**2 + dy**2).values.reshape(-1, 1)
    
    data["spatial_neighborhood_ringKernel"] = kmeans.predict(dist_sq)
    return data

def find_rich_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood'):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby(column)["retailvalue"]
        .agg(metric)
        .sort_values(ascending=False)
    )
    return tmp.head(n).index.tolist()

def find_poor_spatial_neighborhoods(data, n=3, metric=np.median, column = 'spatial_neighborhood'):
    # Top-n clusters by median retailvalue
    tmp = (
        data.groupby(column)["retailvalue"]
        .agg(metric)
        .sort_values(ascending=True)
    )
    return tmp.head(n).index.tolist()

def add_in_rich_neighborhood(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_rich_neighborhood"] = data[column].isin(rich_clusters).astype(int)
    return data

def add_in_poor_neighborhood(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_poor_neighborhood"] = data[column].isin(rich_clusters).astype(int)
    return data

def add_in_city_center(data, rich_clusters, column = 'spatial_neighborhood'):
    data = data.copy()
    data["in_city_center"] = data[column].isin(rich_clusters).astype(int)
    return data



def add_location_terms(data):
    """
    Adds simple nonlinear location terms to allow spatial curvature with linear models.
    """
    data = data.copy()
    data["x2"] = data["x-coor"] ** 2
    data["y2"] = data["y-coor"] ** 2
    data["xy"] = data["x-coor"] * data["y-coor"]
    return data


# the big guns:
def engineered_features(df, is_train=True, knn_model=None, ref_df=None):
    df = df.copy()
    
    # --- A. Domain Knowledge Interactions ---
    # Large house + High Energy Efficiency = Exponentially more valuable
    df['area_energy_interaction'] = df['house-area'] * df['energy-eff']
    
    # "Luxury" Score: A combination of outdoor space and bathrooms
    df['luxury_score'] = df['total_outdoor'] * df['bathrooms']
    
    # Room Density: Are the rooms tiny closets or spacious?
    # (Avoid division by zero)
    df['avg_room_size'] = df['house-area'] / df['bathrooms'].replace(0, 1)
    
    # Age Squared: Captures the "U" shape (New is good, Old is vintage/good, Middle is bad)
    df['age_squared'] = df['house_age'] ** 2
    
    return df

def add_knn_spatial_feature(train_df, test_df, k=15):
    """
    Adds 'spatial_neighbor_log_price' to both Train and Test.
    Train: Uses CV to prevent leakage.
    Test: Uses the full Train set as reference.
    """
    print("Generating KNN Spatial Features...")
    
    # Prepare coordinates
    X_train_coords = train_df[['x-coor', 'y-coor']]
    X_test_coords = test_df[['x-coor', 'y-coor']]
    
    # Target (Log transformed)
    y_train_log = np.log1p(train_df['retailvalue'])
    
    knn = KNeighborsRegressor(n_neighbors=k, weights='distance', n_jobs=-1)
    
    # 1. Train Set: Cross-Validation predictions
    train_preds = cross_val_predict(knn, X_train_coords, y_train_log, cv=10, n_jobs=-1)
    train_df = train_df.copy()
    train_df[f'spatial_neighbor_log_price_{k}'] = train_preds
    
    # 2. Test Set: Train on full Training data, predict on Test
    knn.fit(X_train_coords, y_train_log)
    test_preds = knn.predict(X_test_coords)
    test_df = test_df.copy()
    test_df[f'spatial_neighbor_log_price_{k}'] = test_preds
    
    return train_df, test_df

def fit_clusters_on_train(data):
    """
    Fits all the KMeans models on TRAINING data only.
    Returns a dictionary of models/scalers to use on Test data.
    """
    # 1. Polar
    polar_k, polar_scaler, polar_center = fit_polar_clustering(data, k=20)
    
    # 2. Ring
    ring_k, ring_center = fit_ring_clustering(data, k=4)
    
    # 3. Apply temporary transformations to find rich/poor indices
    temp_data = data.copy()
    temp_data = add_polar_clusters(temp_data, polar_k, polar_scaler, polar_center)
    temp_data = add_ring_clusters(temp_data, ring_k, ring_center)
    
    rich_cluster_3 = find_rich_spatial_neighborhoods(temp_data, n=3, column='spatial_neighborhood_polar')
    poor_cluster_3 = find_poor_spatial_neighborhoods(temp_data, n=3, column='spatial_neighborhood_polar')
    city_center_1 = find_rich_spatial_neighborhoods(temp_data, n=1, column='spatial_neighborhood_ringKernel')
    
    return {
        'polar_k': polar_k, 'polar_scaler': polar_scaler, 'polar_center': polar_center,
        'ring_k': ring_k, 'ring_center': ring_center,
        'rich_cluster_3': rich_cluster_3,
        'poor_cluster_3': poor_cluster_3,
        'city_center_1': city_center_1
    }

# %%
# -------------------------
# Final processing pipeline 
# -------------------------
def process_data_fm(data, cluster_models, is_training=True):
    """
    Refactored to separate FITTING (Train) from TRANSFORMING (Test).
    """
    data = data.copy()
    
    # -------------------
    # Clean Data (ONLY FOR TRAINING)
    # -------------------
    # CRITICAL: Never remove outliers from Test data. You must predict them.
    if is_training:
        data = remove_outliers(data, "house-area", upper=300)

    # -------------------
    # Transform Data
    # -------------------
    data = add_house_age(data)
    data = add_total_outdoor(data)
    data = add_location_terms(data)
    data = engineered_features(data) # Your custom features like area_energy_interaction
    
    # -------------------
    # Apply Clustering (Using Pre-Fitted Models)
    # -------------------
    # We use the models passed in the 'cluster_models' dictionary
    data = add_polar_clusters(data, cluster_models['polar_k'], cluster_models['polar_scaler'], cluster_models['polar_center'])
    data = add_ring_clusters(data, cluster_models['ring_k'], cluster_models['ring_center'])

    # Add boolean features based on the saved "Rich" list
    data = add_in_rich_neighborhood(data, cluster_models['rich_cluster_3'], column='spatial_neighborhood_polar')
    data = add_in_poor_neighborhood(data, cluster_models['poor_cluster_3'], column='spatial_neighborhood_polar')
    data = add_in_city_center(data, cluster_models['city_center_1'], column='spatial_neighborhood_ringKernel')
    
    # -------------------
    # Select Columns
    # -------------------
    # Note: spatial_neighbor_log_price is already in data from the KNN step
    final_cols = [
        "house-area", "bathrooms", "total_outdoor", "house_age",
        "balcony", "energy-eff", "monument", 
        "x-coor", "y-coor", "x2", "y2", "xy",
        "area_energy_interaction", "luxury_score", "avg_room_size", "age_squared",
        "in_rich_neighborhood", "in_poor_neighborhood", "in_city_center",
        "spatial_neighborhood_polar", "spatial_neighborhood_ringKernel"
    ]
    spatial_log_price_columns = [col for col in data.columns if col.startswith('spatial_neighbor_log_price')]
    
    X = data[final_cols+spatial_log_price_columns]
    
    # Standardize? (Optional for XGBoost, but requested)
    # Note: For XGBoost, scaling is irrelevant, but we keep it if you want.
    # To do this correctly, you'd need to fit scaler on train and pass it to test.
    # For simplicity here, we skip it because XGBoost handles unscaled data perfectly.
    
    # log-transform the predictor continuous values
    continuous_cols = ["house-area", "total_outdoor", "house_age", 'x-coor', 'y-coor', 'x2', 'y2', 'xy', 'area_energy_interaction', 'luxury_score', 'avg_room_size', 'age_squared']
    X[continuous_cols] = X[continuous_cols].apply(np.log1p)
    
    y = np.log1p(data["retailvalue"])
    
    return X, y

# %%
# =========================
# Train/test split (single file)
# =========================
#reloading the data jst in case, same train/test spit
full_data = pd.read_csv("utrechthousing.csv")
train_df, test_df = train_test_split(full_data, test_size=0.2, random_state=1983)

for k in range(5,21,1):
    train_df, test_df = add_knn_spatial_feature(train_df, test_df, k=k)

# 3. Fit Cluster Models on TRAIN only
print("Fitting Cluster Models on Train Data...")
cluster_models = fit_clusters_on_train(train_df)

# pre-process data
X_train, y_train = process_data_fm(train_df, cluster_models, is_training=True)
X_test, y_test = process_data_fm(test_df, cluster_models, is_training=False)

# full_X, full_y = process_data_fm(full_data, standardized=False)
# Out:
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Generating KNN Spatial Features...
# Fitting Cluster Models on Train Data...
# /var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/3575979172.py:150: FutureWarning: The provided callable <function median at 0x10717cc20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   .agg(metric)
# /var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/3575979172.py:159: FutureWarning: The provided callable <function median at 0x10717cc20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   .agg(metric)
# /var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/886250959.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[continuous_cols] = X[continuous_cols].apply(np.log1p)
# /var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/886250959.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[continuous_cols] = X[continuous_cols].apply(np.log1p)

# %%
import optuna

# Define the objective function for Optuna
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 5000, 15000, step=500),
        'max_depth': trial.suggest_int('max_depth', 1, 5),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1, log=True)
    }
    
    model = xgb.XGBRegressor(**params, n_jobs=-1, random_state=42)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    return rmse(np.expm1(y_test), np.expm1(preds))

# Run Optuna optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)
print("Best Hyperparameters:", study.best_params)
# Train final model with best hyperparameters from Optuna
best_params_optuna = study.best_params
final_model_optuna = xgb.XGBRegressor(**best_params_optuna, random_state=42)
final_model_optuna.fit(X_train, y_train)
final_preds_optuna = final_model_optuna.predict(X_test)
final_rmse_optuna = rmse(np.expm1(y_test), np.expm1(final_preds_optuna))
print(f"Final Test RMSE with Optuna: {final_rmse_optuna}")
# Out:
# [I 2026-02-12 10:25:07,312] A new study created in memory with name: no-name-b05fc539-ecda-4f7b-a3ae-d3c0f36abd3d
# [I 2026-02-12 10:25:14,112] Trial 0 finished with value: 17162.099102915334 and parameters: {'n_estimators': 9500, 'max_depth': 2, 'reg_lambda': 1.8691331542624439, 'reg_alpha': 0.5545063446993056, 'learning_rate': 0.002425854425032775}. Best is trial 0 with value: 17162.099102915334.
# [I 2026-02-12 10:25:24,373] Trial 1 finished with value: 11682.767346759243 and parameters: {'n_estimators': 14500, 'max_depth': 2, 'reg_lambda': 3.743897106467715, 'reg_alpha': 0.17038380700376055, 'learning_rate': 0.005782565961335263}. Best is trial 1 with value: 11682.767346759243.
# [I 2026-02-12 10:25:30,407] Trial 2 finished with value: 14005.933975575372 and parameters: {'n_estimators': 14500, 'max_depth': 5, 'reg_lambda': 2.8410790297639803, 'reg_alpha': 0.5792440576033893, 'learning_rate': 0.02156622171003393}. Best is trial 1 with value: 11682.767346759243.
# [I 2026-02-12 10
. Best is trial 77 with value: 9863.12465292992.
# [I 2026-02-12 13:33:37,316] Trial 145 finished with value: 10000.308221565627 and parameters: {'n_estimators': 10000, 'max_depth': 2, 'reg_lambda': 1.1086891428128132, 'reg_alpha': 0.03747411603719357, 'learning_rate': 0.023185653658333024}. Best is trial 77 with value: 9863.12465292992.
# [I 2026-02-12 13:33:44,290] Trial 146 finished with value: 10281.452979221172 and parameters: {'n_estimators': 10000, 'max_depth': 2, 'reg_lambda': 1.204659368473032, 'reg_alpha': 0.002807354463512029, 'learning_rate': 0.023866583477069308}. Best is trial 77 with value: 9863.12465292992.
# [I 2026-02-12 13:33:50,753] Trial 147 finished with value: 9929.294041436064 and parameters: {'n_estimators': 10500, 'max_depth': 2, 'reg_lambda': 1.0220186800640927, 'reg_alpha': 0.028932157898956333, 'learning_rate': 0.028339093901081185}. Best is trial 77 with value: 9863.12465292992.
# [W 2026-02-12 13:33:56,744] Trial 148 failed with parameters: {'n_estimators': 9500, 'max_depth': 2, 'reg_lambda': 1.0899978645248856, 'reg_alpha': 0.043270285648153606, 'learning_rate': 0.023961272905083167} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/var/folders/84/sbq4d0yx2vdcrx0_5_cy2hmh0000gn/T/ipykernel_6496/3292462603.py", line 14, in objective
#     model.fit(X_train, y_train)
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/xgboost/core.py", line 751, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/xgboost/sklearn.py", line 1368, in fit
#     self._Booster = train(
#                     ^^^^^^
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/xgboost/core.py", line 751, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/xgboost/training.py", line 200, in train
#     bst.update(dtrain, iteration=i, fobj=obj)
#   File "/Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/xgboost/core.py", line 2391, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2026-02-12 13:33:56,745] Trial 148 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/maksiuuuuuuu/Desktop/Data Analysis/clinic2/DA-clinic2.ipynb Cell 100 line 2
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=17'>18</a> # Run Optuna optimization
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=18'>19</a> study = optuna.create_study(direction='minimize')
# ---> <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=19'>20</a> study.optimize(objective, n_trials=1000)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=20'>21</a> print("Best Hyperparameters:", study.best_params)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=21'>22</a> # Train final model with best hyperparameters from Optuna
#
# File ~/Library/Python/3.12/lib/python/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/Library/Python/3.12/lib/python/site-packages/optuna/study/_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File ~/Library/Python/3.12/lib/python/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File ~/Library/Python/3.12/lib/python/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File ~/Library/Python/3.12/lib/python/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# /Users/maksiuuuuuuu/Desktop/Data Analysis/clinic2/DA-clinic2.ipynb Cell 100 line 1
#       <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=4'>5</a> params = {
#       <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=5'>6</a>     'n_estimators': trial.suggest_int('n_estimators', 5000, 15000, step=500),
#       <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=6'>7</a>     'max_depth': trial.suggest_int('max_depth', 1, 5),
#    (...)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=9'>10</a>     'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1, log=True)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=10'>11</a> }
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=12'>13</a> model = xgb.XGBRegressor(**params, n_jobs=-1, random_state=42)
# ---> <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=13'>14</a> model.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=14'>15</a> preds = model.predict(X_test)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y226sZmlsZQ%3D%3D?line=15'>16</a> return rmse(np.expm1(y_test), np.expm1(preds))
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/sklearn.py:1368, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1365 else:
#    1366     obj = None
# -> 1368 self._Booster = train(
#    1369     params,
#    1370     train_dmatrix,
#    1371     self.get_num_boosting_rounds(),
#    1372     evals=evals,
#    1373     early_stopping_rounds=self.early_stopping_rounds,
#    1374     evals_result=evals_result,
#    1375     obj=obj,
#    1376     custom_metric=metric,
#    1377     verbose_eval=verbose,
#    1378     xgb_model=model,
#    1379     callbacks=self.callbacks,
#    1380 )
#    1382 self._set_evaluation_result(evals_result)
#    1383 return self
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/training.py:200, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     198 if cb_container.before_iteration(bst, i, dtrain, evals):
#     199     break
# --> 200 bst.update(dtrain, iteration=i, fobj=obj)
#     201 if cb_container.after_iteration(bst, i, dtrain, evals):
#     202     break
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/core.py:2391, in Booster.update(self, dtrain, iteration, fobj)
#    2387 self._assign_dmatrix_features(dtrain)
#    2389 if fobj is None:
#    2390     _check_call(
# -> 2391         _LIB.XGBoosterUpdateOneIter(
#    2392             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2393         )
#    2394     )
#    2395     return
#    2397 # Forward the gradient calculation to the boost method.
#
# KeyboardInterrupt:

# %%
[I 2026-02-11 21:16:49,326] Trial 275 finished with value: 8801.821167653612 and parameters: {'n_estimators': 36500, 'max_depth': 2, 'reg_lambda': 52.997409223973705, 'reg_alpha': 0.03942090289834921, 'subsample': 0.5385047448985946, 'colsample_bytree': 0.9495658782774802, 'learning_rate': 0.07301489293126373}. Best is trial 275 with value: 8801.821167653612.

Trial 1359 finished with value: 8394.100185803027 and parameters: {'n_estimators': 35000, 'max_depth': 2, 'reg_lambda': 1.9564167510363355, 'reg_alpha': 0.01602551569442586, 'subsample': 0.6468775042640683, 'colsample_bytree': 0.9693897431442812, 'learning_rate': 0.04839155846431969}. Best is trial 1359 with value: 8394.100185803027.
[

# %%
# lasso regression with hyperparamter tuning
from sklearn.linear_model import LassoCV

lasso_cv = LassoCV(alphas=np.arange(0.001, 100, 0.5), cv=10, n_jobs=-1)
lasso_cv.fit(X_train, y_train)
best_alpha = lasso_cv.alpha_
print(f"Best alpha from LassoCV: {best_alpha}")
lasso_final = lm.Lasso(alpha=best_alpha, random_state=42)
lasso_final.fit(X_train, y_train)
lasso_preds = lasso_final.predict(X_test)
lasso_rmse = rmse(np.expm1(y_test), np.expm1(lasso_preds))
print(f"Final Test RMSE with LassoCV: {lasso_rmse}")
# Out:
# Best alpha from LassoCV: 0.001
# Final Test RMSE with LassoCV: 23824.526560569735

# %%
# ==========================================
# 4. MODELING (The Big Guns)
# ==========================================

# hyperparameter tunning
 


model = xgb.XGBRegressor(
    n_estimators=35000,       
    learning_rate=0.04839155846431969,      
    max_depth=4,             
    subsample=0.6468775042640683,           
    colsample_bytree=0.9693897431442812,    
    n_jobs=-1,
    random_state=42,
    reg_lambda=2,
    reg_alpha=0.01602551569442586
)


print("Training XGBoost...")
model.fit(X_train, y_train,verbose=500)

# ==========================================
# 5. EVALUATION (Fixing the RMSE Bug)
# ==========================================

# Predict (Log Scale)
log_preds = model.predict(X_test)

# Convert Preds to Real Scale
real_preds = np.expm1(log_preds)

# Convert y_test to Real Scale (Because y_test comes from process_data_fm as Log)
real_y_test = np.expm1(y_test)

# Calculate RMSE on Real Prices
final_rmse = np.sqrt(mean_squared_error(real_y_test, real_preds))

print(f"\n=============================================")
print(f"FINAL TEST RMSE: {final_rmse:,.2f}")
print(f"=============================================")

# Plot
xgb.plot_importance(model, max_num_features=40)
plt.title("Feature Importance")
plt.show()
# Out:
# Training XGBoost...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/maksiuuuuuuu/Desktop/Data Analysis/clinic2/DA-clinic2.ipynb Cell 103 line 2
#       <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=8'>9</a> model = xgb.XGBRegressor(
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=9'>10</a>     n_estimators=35000,
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=10'>11</a>     learning_rate=0.04839155846431969,
#    (...)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=18'>19</a>     early_stopping_rounds=100,
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=19'>20</a> )
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=22'>23</a> print("Training XGBoost...")
# ---> <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=23'>24</a> model.fit(X_train, y_train,verbose=500)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=25'>26</a> # ==========================================
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=26'>27</a> # 5. EVALUATION (Fixing the RMSE Bug)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=27'>28</a> # ==========================================
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=28'>29</a>
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=29'>30</a> # Predict (Log Scale)
#      <a href='vscode-notebook-cell:/Users/maksiuuuuuuu/Desktop/Data%20Analysis/clinic2/DA-clinic2.ipynb#Y224sZmlsZQ%3D%3D?line=30'>31</a> log_preds = model.predict(X_test)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/sklearn.py:1368, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1365 else:
#    1366     obj = None
# -> 1368 self._Booster = train(
#    1369     params,
#    1370     train_dmatrix,
#    1371     self.get_num_boosting_rounds(),
#    1372     evals=evals,
#    1373     early_stopping_rounds=self.early_stopping_rounds,
#    1374     evals_result=evals_result,
#    1375     obj=obj,
#    1376     custom_metric=metric,
#    1377     verbose_eval=verbose,
#    1378     xgb_model=model,
#    1379     callbacks=self.callbacks,
#    1380 )
#    1382 self._set_evaluation_result(evals_result)
#    1383 return self
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/training.py:201, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     199         break
#     200     bst.update(dtrain, iteration=i, fobj=obj)
# --> 201     if cb_container.after_iteration(bst, i, dtrain, evals):
#     202         break
#     204 bst = cb_container.after_training(bst)
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/callback.py:268, in CallbackContainer.after_iteration(self, model, epoch, dtrain, evals)
#     266     metric_score = _parse_eval_str(score)
#     267     self._update_history(metric_score, epoch)
# --> 268 ret = any(c.after_iteration(model, epoch, self.history) for c in self.callbacks)
#     269 return ret
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/callback.py:268, in <genexpr>(.0)
#     266     metric_score = _parse_eval_str(score)
#     267     self._update_history(metric_score, epoch)
# --> 268 ret = any(c.after_iteration(model, epoch, self.history) for c in self.callbacks)
#     269 return ret
#
# File ~/Library/Python/3.12/lib/python/site-packages/xgboost/callback.py:460, in EarlyStopping.after_iteration(self, model, epoch, evals_log)
#     458 msg = "Must have at least 1 validation dataset for early stopping."
#     459 if len(evals_log.keys()) < 1:
# --> 460     raise ValueError(msg)
#     462 # Get data name
#     463 if self.data:
#
# ValueError: Must have at least 1 validation dataset for early stopping.

# %% [markdown]
# ## TODO
# 1. standardize predictors (according to their distribution!)
# 2. check all predictior outliers!
# 3. check all features for type of relationship!

# %%
# I wanna see the relationship between each feature and the target!
# This allows us to check for potential polynomial feature transforms and removing outliers
# plot all features against the target on subplots for readibility, scatter for continuous features, boxplot for categorical features
continuous_features = ['house-area', 'total_outdoor', 'house_age', 'x-coor', 'y-coor', 'x2', 'y2', 'xy']
categorical_features = ['bathrooms', 'balcony', 'energy-eff', 'monument', 'in_rich_neighborhood', 'in_poor_neighborhood', 'in_city_center']
fig, axes = plt.subplots(5, 3, figsize=(18, 15))
for i, feature in enumerate(continuous_features[:5]):
    sns.scatterplot(x=full_X[feature], y=full_y, ax=axes[i, 0])
    axes[i, 0].set_title(f"{feature} vs. Retail Value")
    axes[i, 0].set_xlabel(feature)
    axes[i, 0].set_ylabel("Retail Value")
for i, feature in enumerate(continuous_features[5:]):
    sns.scatterplot(x=full_X[feature], y=full_y, ax=axes[i, 1])
    axes[i, 1].set_title(f"{feature} vs. Retail Value")
    axes[i, 1].set_xlabel(feature)
    axes[i, 1].set_ylabel("Retail Value")
for i, feature in enumerate(categorical_features[:2]):
    sns.boxplot(x=full_X[feature], y=full_y, ax=axes[i+3, 1])
    axes[i+3, 1].set_title(f"{feature} vs. Retail Value")
    axes[i+3, 1].set_xlabel(feature)
    axes[i+3, 1].set_ylabel("Retail Value")
for i, feature in enumerate(categorical_features[2:]):
    sns.boxplot(x=full_X[feature], y=full_y, ax=axes[i, 2])
    axes[i, 2].set_title(f"{feature} vs. Retail Value")
    axes[i, 2].set_xlabel(feature)
    axes[i, 2].set_ylabel("Retail Value")
plt.tight_layout()

# %%
# ============================
# Final model (the big winner)
# ============================
\

# Evaluate
# y_pred_train = final_model.predict(X_train)
# y_pred_test = final_model.predict(X_test)

#training_score = rmse(y_train, y_pred_train)
#test_score = rmse(y_test, y_pred_test)

#print("Chosen alpha:", final_model.alpha_)
#print("Chosen l1_ratio:", final_model.l1_ratio_)
#print("Training RMSE:", training_score)
#print("Test RMSE:", test_score)

# Optional: see which features survived regularization
#coef = pd.Series(final_model.coef_, index=X_train.columns).sort_values(key=np.abs, ascending=False)
#print("\nTop coefficients by absolute value:")
#print(coef.head(15))

#something else?
# Out:
# Training RMSE: 5520.139980622213
# Test RMSE: 16017.213335915942
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.231e+11, tolerance: 5.164e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.416e+11, tolerance: 5.574e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.392e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.361e+11, tolerance: 5.449e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:681: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.354e+11, tolerance: 5.242e+09
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/maksiuuuuuuu/Library/Python/3.12/lib/python/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.756e+11, tolerance: 6.720e+09
#   model = cd_fast.enet_coordinate_descent(
# Training RMSE: 15236.877326026495
# Test RMSE: 16370.067150457013
# Training RMSE: 18191.427308383405
# Test RMSE: 44197.82994855958

# %%
# training_data = pd.read_csv('ames_train.csv')
# X_train, y_train = process_data_fm(training_data)
# final_model.fit(X_train, y_train)

# %% [markdown]
# # 4. Assessing Feature Importance via Perturbation Tests
#
# So far, we have evaluated our models using prediction error. However, understanding **which features drive predictions** is equally important — especially when models are used in socially sensitive contexts such as housing valuation.
#
# One intuitive way to assess feature importance is through a **perturbation (permutation) test**. The idea is simple (and we discussed it in class after regularization - so refer to the slides of Chapter/Lecture VI as well):
#
# > If a feature is important, randomly shuffling its values should significantly worsen model performance.
#
# This breaks the relationship between the feature and the target while keeping the rest of the data unchanged.
#
# ---
#
# ### 🔍 Intuition
#
# - Small change in RMSE → feature not very important
# - Large increase in RMSE → feature highly influential
#
# ---
#
# ### 📋 Procedure
#
# 1. Measure the original model RMSE on the test set
# 2. For each feature:
#    - Shuffle its values in the test data
#    - Recompute RMSE
#    - Record the increase in error

# %% [markdown]
# ### Question 6
#
# Implement a perturbation test to estimate the importance of each feature in your model.
#
# Answer the following questions:
#
# - Which features appear most influential?
# - Are any features surprisingly unimportant?
# - (include any other interesting observation you make)
#
# Reflect briefly on what this means for both prediction performance and fairness.

# %%
def perturbation_importance(model, X_test, y_test, metric=rmse):
    """
    Computes feature importance via perturbation tests.
    
    Returns a Series indexed by feature name with RMSE increase values.
    """
    
    return []

# %%
# 1) Make sure we use the model that was actually fit
# (final_model was fit on X_train from process_data_fm)
model = final_model

# Align feature columns (protects against column order / missing dummies / extra columns)
#X_test_aligned = X_test.reindex(columns=X_train.columns, fill_value=0)

feature_importance = perturbation_importance(
    model, 
    X_test, 
    y_test
)

feature_importance

# %%
plt.figure(figsize=(10,6))
feature_importance.plot(kind="bar")
plt.ylabel("Increase in RMSE after perturbation")
plt.title("Feature Importance via Perturbation Test")
plt.show()

# %% [markdown]
# ### ** Analysis and answers to questions goes here**
#
# more text goes here

# %% [markdown]
# # 5. Assessing Fairness Through Error Analysis Across Locations
#
# High predictive accuracy does not necessarily imply a fair model. In housing valuation, systematic over- or under-estimation in certain areas may disproportionately affect specific communities.
#
# To explore potential fairness issues, we examine whether prediction errors differ across geographic groups, such as zip codes or spatial neighborhoods.
#
# If the model consistently:
#
# - Overestimates values in some areas
# - Underestimates values in others
#
# this may indicate unequal treatment depending on the location your house is in.
#
# ---
#
# ### 📋 Procedure
#
# 1. Compute prediction errors for each house:
#
#    Error = Actual Value − Predicted Value
#
# 2. Group errors by geographic category (e.g., zip code or spatial cluster)
#
# 3. Compare average error and RMSE across groups
#
# ---
#
# ### Question 7
#
# Analyze whether prediction errors differ systematically across locations.
#
# Answer the following:
#
# - Are some neighborhoods consistently overvalued or undervalued?
# - Which areas show the largest prediction errors?
# - What might explain these patterns?
#
# (any other observation you think is worth mentioning)

# %%
# Might be handy to create a results DataFrame
fairness_df = testing_data.copy()

fairness_df["prediction"] = y_pred_test
fairness_df["error"] = fairness_df["retailvalue"] - fairness_df["prediction"]
fairness_df["abs_error"] = np.abs(fairness_df["error"])

# %%
# compute the error per-zipcode (hint: use groupby and agg?)

# %%
#plot figure and show any differences?

# %% [markdown]
# ### ** Analysis and answers to questions goes here**
#
# more text goes here
